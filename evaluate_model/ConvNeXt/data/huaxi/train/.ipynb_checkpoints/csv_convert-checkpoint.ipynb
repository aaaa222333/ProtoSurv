# %%
import pandas as pd

# 读取CSV
df = pd.read_csv("/home/user/prognosis_lst/evaluate_model/ConvNeXt/data/huaxi/test/final_complete_with_paths.csv")

# 1. 查看各列的数据类型
print("各列当前格式:")
print(df.dtypes)

# 2. 查看前几行数据
print("\n前3行数据:")
print(df.head(3))

# 3. 查看每列的唯一值（对分类变量有用）
print("\n每列唯一值示例:")
for col in df.columns:
    print(f"{col}: {df[col].unique()[:5]}")  # 显示前5个唯一值
# Out:
# 各列当前格式:
# feature_path     object
# label           float64
# dtype: object
#
# 前3行数据:
#                                         feature_path  label
# 0  /home/user/prognosis_lst/feature/huaxi/test/03...    1.0
# 1  /home/user/prognosis_lst/feature/huaxi/test/0d...    1.0
# 2  /home/user/prognosis_lst/feature/huaxi/test/15...    0.0
#
# 每列唯一值示例:
# feature_path: ['/home/user/prognosis_lst/feature/huaxi/test/035e8716e8e37798775cf3a286b11db5.pt'
#  '/home/user/prognosis_lst/feature/huaxi/test/0df9d96be489f8e027ed93979d54db52.pt'
#  '/home/user/prognosis_lst/feature/huaxi/test/152d03e33ea11eefbfbd3e6aed46b2b5.pt'
#  '/home/user/prognosis_lst/feature/huaxi/test/1f3d9c5a74ae58f57703eeb9152b2684.pt'
#  '/home/user/prognosis_lst/feature/huaxi/test/21ce1f09371fef672bdf11e0d9009bbc.pt']
# label: [1. 0.]

# %%
df['label'] = df['label'].astype(int)   # 0,1,2...

# %%
df.to_csv("/home/user/prognosis_lst/evaluate_model/ConvNeXt/data/huaxi/test/final_complete_with_paths.csv", index=False)
