# %%
import pandas as pd
import os

# 读取CSV
df = pd.read_csv("final_complete.csv")

base_path = "/home/user/prognosis_lst/feature/huaxi/train"

# 使用apply创建新列
df['feature_path'] = df['unique_id'].apply(lambda x: os.path.join(base_path, f"{x}.pt"))

# 查看结果
print(df.head())

# 保存（可以选择只保存需要的列）
df[['feature_path', 'label']].to_csv("final_complete_with_paths.csv", index=False)

print(f"已保存到: final_complete_with_paths.csv")
# Out:
#    Unnamed: 0.1  Unnamed: 0                         unique_id  \
# 0             0           0  004e8a14335ab457e9c50fee56691e72
# 1             1           1  00792fea33f8cfbebb2bd9ac15c2423b
# 2             2           2  015821541563a662a1786ff37b589b0d
# 3             3           3  0173fe0e2ad8346ca89b09f587d20e11
# 4             4           4  020d2afbafee1ef92c4ffc085b0d5495
#
#                                                 path  label  \
# 0  /data1/lcc/EGFR/HUAXI_PFS/retrospective/lungSe...    1.0
# 1  /data1/lcc/EGFR/HUAXI_PFS/retrospective/lungSe...    0.0
# 2  /data1/lcc/EGFR/HUAXI_PFS/retrospective/lungSe...    0.0
# 3  /data1/lcc/EGFR/HUAXI_PFS/retrospective/lungSe...    0.0
# 4  /data1/lcc/EGFR/HUAXI_PFS/retrospective/lungSe...    1.0
#
#                                         feature_path
# 0  /home/user/prognosis_lst/feature/huaxi/train/0...
# 1  /home/user/prognosis_lst/feature/huaxi/train/0...
# 2  /home/user/prognosis_lst/feature/huaxi/train/0...
# 3  /home/user/prognosis_lst/feature/huaxi/train/0...
# 4  /home/user/prognosis_lst/feature/huaxi/train/0...
# 已保存到: final_complete_with_paths.csv
