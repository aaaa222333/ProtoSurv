# %%
import pandas as pd
import os

# 读取CSV
df = pd.read_csv("/home/user/prognosis_lst/evaluate_model/ConvNeXt/data/huaxi/val/final_complete_ori.csv")

base_path = "/home/user/prognosis_lst/feature/huaxi/val"

# 使用apply创建新列
df['feature_path'] = df['unique_id'].apply(lambda x: os.path.join(base_path, f"{x}.pt"))

# 查看结果
print(df.head())

# 保存（可以选择只保存需要的列）
df[['feature_path', 'label']].to_csv("/home/user/prognosis_lst/evaluate_model/ConvNeXt/data/huaxi/val/final_complete_with_paths_ori.csv", index=False)

print(f"已保存到: final_complete_with_paths.csv")
# Out:
#    Unnamed: 0.1  Unnamed: 0                         unique_id  \
# 0             0           0  00aa0acc7a8df8932598be9240e3a0e7
# 1             1           1  0df9d96be489f8e027ed93979d54db52
# 2             2           2  152d03e33ea11eefbfbd3e6aed46b2b5
# 3             3           3  1f3d9c5a74ae58f57703eeb9152b2684
# 4             4           4  206c6e6efb212405bf74b7c248d49654
#
#                                                 path  label  \
# 0  /data1/lcc/EGFR/HUAXI_PFS/retrospective/lungSe...      1
# 1  /data1/lcc/EGFR/HUAXI_PFS/retrospective/lungSe...      0
# 2  /data1/lcc/EGFR/HUAXI_PFS/retrospective/lungSe...      1
# 3  /data1/lcc/EGFR/HUAXI_PFS/retrospective/lungSe...      1
# 4  /storedata1/proccessed/HUAXI_with_annos/resamp...      0
#
#                                         feature_path
# 0  /home/user/prognosis_lst/feature/huaxi/val/00a...
# 1  /home/user/prognosis_lst/feature/huaxi/val/0df...
# 2  /home/user/prognosis_lst/feature/huaxi/val/152...
# ...

# %%
import pandas as pd
import os

# 读取CSV
df = pd.read_csv("/home/user/prognosis_lst/evaluate_model/ConvNeXt/data/huaxi/val/final_complete.csv")

base_path = "/home/user/prognosis_lst/feature/huaxi/val"

# 使用apply创建新列
df['feature_path'] = df['unique_id'].apply(lambda x: os.path.join(base_path, f"{x}.pt"))

# 查看结果
print(df.head())

# 保存（可以选择只保存需要的列）
df[['feature_path', 'label']].to_csv("/home/user/prognosis_lst/evaluate_model/ConvNeXt/data/huaxi/val/final_complete_with_paths.csv", index=False)

print(f"已保存到: final_complete_with_paths.csv")
