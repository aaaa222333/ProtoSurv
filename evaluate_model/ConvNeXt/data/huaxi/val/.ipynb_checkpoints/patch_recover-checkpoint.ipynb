# %%
import pandas as pd
import os

# 读取CSV
df = pd.read_csv("final_complete.csv")

base_path = "/home/user/prognosis_lst/feature/huaxi/val"

# 使用apply创建新列
df['feature_path'] = df['unique_id'].apply(lambda x: os.path.join(base_path, f"{x}.pt"))

# 查看结果
print(df.head())

# 保存（可以选择只保存需要的列）
df[['feature_path', 'label']].to_csv("final_complete_with_paths.csv", index=False)

print(f"已保存到: final_complete_with_paths.csv")
# Out:
#    Unnamed: 0.1  Unnamed: 0                         unique_id  \
# 0             0           0  00aa0acc7a8df8932598be9240e3a0e7
# 1             1           1  21b5b9de632efe21573b357f7bc529ac
# 2             2           2  24c647c4f07702d8442f7e43eb26e965
# 3             3           3  26010a228ac2fffb78e7eccf426c9efe
# 4             4           4  2da73a577c7925c258273959ce038ae7
#
#                                                 path  label  \
# 0  /data1/lcc/EGFR/HUAXI_PFS/retrospective/lungSe...    0.0
# 1  /data1/lcc/EGFR/HUAXI_PFS/retrospective/lungSe...    1.0
# 2  /data1/lcc/EGFR/HUAXI_PFS/retrospective/lungSe...    1.0
# 3  /data1/lcc/EGFR/HUAXI_PFS/retrospective/lungSe...    0.0
# 4  /data1/lcc/EGFR/HUAXI_PFS/retrospective/lungSe...    1.0
#
#                                         feature_path
# 0  /home/user/prognosis_lst/feature/huaxi/val/00a...
# 1  /home/user/prognosis_lst/feature/huaxi/val/21b...
# 2  /home/user/prognosis_lst/feature/huaxi/val/24c...
# 3  /home/user/prognosis_lst/feature/huaxi/val/260...
# 4  /home/user/prognosis_lst/feature/huaxi/val/2da...
# 已保存到: final_complete_with_paths.csv
