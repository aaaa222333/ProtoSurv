# %%
import pandas as pd
import os

# 读取CSV
df = pd.read_csv("final_complete.csv")

base_path = "/home/user/prognosis_lst/feature/huaxi/pretrain/train"

# 使用apply创建新列
df['feature_path'] = df['unique_id'].apply(lambda x: os.path.join(base_path, f"{x}.pt"))

# 查看结果
print(df.head())

# 保存（可以选择只保存需要的列）
df[['feature_path', 'text']].rename(columns={'text': 'label'}).to_csv("final_complete_with_paths.csv", index=False)

print(f"已保存到: final_complete_with_paths.csv")
# Out:
#    Unnamed: 0.1  Unnamed: 0                         unique_id  \
# 0             0           0  0000c274e6b1f59d771f93495a850d9f
# 1             1           1  0000ea1a4cd0c2923d9f2f0effa7c9af
# 2             2           2  000135e6149f864099ea8316af0e6ab2
# 3             3           3  00017d163b3471602d421af527e10543
# 4             4           4  000180d4e1c10cb8422f3de1401be6ef
#
#                                                 path  text  \
# 0  /storedata1/proccessed/henan/resized_img/bm_00...     1
# 1  /storedata1/proccessed/jilin/resized_img/jdyy-...     1
# 2  /storedata1/proccessed/jilin/resized_img/jdyy-...     1
# 3  /storedata1/proccessed/jilin/resized_img/jdyy-...     1
# 4  /storedata1/proccessed/qilu2/resized_img/00086...     1
#
#                                         feature_path
# 0  /home/user/prognosis_lst/feature/huaxi/pretrai...
# 1  /home/user/prognosis_lst/feature/huaxi/pretrai...
# 2  /home/user/prognosis_lst/feature/huaxi/pretrai...
# ...
