# %%
import pandas as pd
import os

# 读取CSV
df = pd.read_csv("final_complete.csv")

base_path = "/home/user/prognosis_lst/feature/lung1/train"

# 使用apply创建新列
df['feature_path'] = df['unique_id'].apply(lambda x: os.path.join(base_path, f"{x}.pt"))

# 查看结果
print(df.head())

# 保存（可以选择只保存需要的列）
df[['feature_path', 'label']].to_csv("final_complete_with_paths.csv", index=False)

print(f"已保存到: final_complete_with_paths.csv")
# Out:
#    Unnamed: 0.1  Unnamed: 0                         unique_id  \
# 0             0           0  0099115cd8e7d6001169f274dee38065
# 1             1           1  00d69fc44959e3a78d1951fe7f1bc56d
# 2             2           2  014915e1e43272158df5c35874702f87
# 3             3           3  015baabcf7df204692c9c1d6157131ea
# 4             4           4  02249bfa954bfb043ac00cb9cda0d897
#
#                                                 path  label  \
# 0  /storedata1/proccessed/NSCLC/NSCLC_Radiomics_L...      1
# 1  /storedata1/proccessed/NSCLC/NSCLC_Radiomics_L...      0
# 2  /storedata1/proccessed/NSCLC/NSCLC_Radiomics_L...      0
# 3  /storedata1/proccessed/NSCLC/NSCLC_Radiomics_L...      0
# 4  /storedata1/proccessed/NSCLC/NSCLC_Radiomics_L...      1
#
#                                         feature_path
# 0  /home/user/prognosis_lst/feature/lung1/train/0...
# 1  /home/user/prognosis_lst/feature/lung1/train/0...
# 2  /home/user/prognosis_lst/feature/lung1/train/0...
# 3  /home/user/prognosis_lst/feature/lung1/train/0...
# 4  /home/user/prognosis_lst/feature/lung1/train/0...
# 已保存到: final_complete_with_paths.csv
