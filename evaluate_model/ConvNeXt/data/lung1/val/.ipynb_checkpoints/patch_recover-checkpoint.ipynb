# %%
import pandas as pd
import os

# 读取CSV
df = pd.read_csv("final_complete.csv")

base_path = "/home/user/prognosis_lst/feature/dalina/train"

# 使用apply创建新列
df['feature_path'] = df['unique_id'].apply(lambda x: os.path.join(base_path, f"{x}.pt"))

# 查看结果
print(df.head())

# 保存（可以选择只保存需要的列）
df[['feature_path', 'label']].to_csv("final_complete_with_paths.csv", index=False)

print(f"已保存到: final_complete_with_paths.csv")
# Out:
#    Unnamed: 0.1  Unnamed: 0                         unique_id  \
# 0             0           0  009190a41cc51cecda7f659ace806b69
# 1             1           1  0136097759a9212a3db054ceb6e1514a
# 2             2           2  0187528f2a4dab01af7c9dbe1d88c0cb
# 3             3           3  02bcaf17d4a6c8a03d640040ae80e955
# 4             4           4  0304d47c22c6fbc91d388922fcf18971
#
#                                                 path  label  \
# 0  /storedata1/proccessed/dalian/lung/tumor_32646...      1
# 1  /storedata1/proccessed/dalian/lung/tumor_32646...      0
# 2  /storedata1/proccessed/dalian/lung/tumor_32646...      1
# 3  /storedata1/proccessed/dalian/lung/tumor_32646...      1
# 4  /storedata1/proccessed/dalian/lung/tumor_32646...      0
#
#                                         feature_path
# 0  /home/user/prognosis_lst/feature/dalina/train/...
# 1  /home/user/prognosis_lst/feature/dalina/train/...
# 2  /home/user/prognosis_lst/feature/dalina/train/...
# 3  /home/user/prognosis_lst/feature/dalina/train/...
# 4  /home/user/prognosis_lst/feature/dalina/train/...
# 已保存到: final_complete_with_paths.csv
