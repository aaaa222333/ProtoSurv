# %%
import pandas as pd

# 读取两个文件（没有表头）
df1 = pd.read_csv('processed_rank_0.csv', header=None)
df2 = pd.read_csv('processed_rank_0.csv', header=None)

# 添加列名方便操作
df1.columns = ['unique_id', 'path']
df2.columns = ['unique_id', 'path']

# 以第二列（unique_id）为唯一值合并
merged_df = pd.merge(df1, df2, on='unique_id', how='outer',suffixes=('_file1', '_file2'))

merged_df['path'] = merged_df['path_file1'].combine_first(merged_df['path_file2'])

# 保存结果

result = merged_df[['unique_id', 'path']].drop_duplicates(subset='unique_id', keep='first')
result.to_csv('merged_output.csv', index=True, header=True)

print(f"原始文件1行数: {len(df1)}")
print(f"原始文件2行数: {len(df2)}")
print(f"合并后行数: {len(result)}")
# Out:
# 原始文件1行数: 21
# 原始文件2行数: 21
# 合并后行数: 21

# %%
import pandas as pd

# 1. 合并path文件
path_df = pd.read_csv("merged_output.csv")
# 2. 读取pred文件
pred_df = pd.read_csv('val.csv')  # 如果有表头
# pred_df = pd.read_csv('pred.csv', header=None, names=['index', 'imgPath', 'pred'])  # 如果无表头

# 3. 左连接合并
result = pd.merge(
    path_df,
    pred_df[['imgPath', 'label']],
    left_on='path',
    right_on='imgPath',
    how='left'
).drop('imgPath', axis=1)

# 4. 找出缺失的
missing = result[result['label'].isna()]
print(f"缺失pred的记录数: {len(missing)}")
if len(missing) > 0:
    missing.to_csv('missing_records.csv', index=False)
    print("缺失记录已保存")

result.to_csv('final_complete.csv', index=True)
print("完成！")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       4 path_df = pd.read_csv("merged_output.csv")
#       5 # 2. 读取pred文件
# ----> 6 pred_df = pd.read_csv('train.csv')  # 如果有表头
#       7 # pred_df = pd.read_csv('pred.csv', header=None, names=['index', 'imgPath', 'pred'])  # 如果无表头
#       8
#       9 # 3. 左连接合并
#      10 result = pd.merge(
#      11     path_df,
#      12     pred_df[['imgPath', 'label']],
#    (...)
#      15     how='left'
#      16 ).drop('imgPath', axis=1)
#
# File ~/.conda/envs/bigmodel_clone/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.conda/envs/bigmodel_clone/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.conda/envs/bigmodel_clone/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.conda/envs/bigmodel_clone/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/.conda/envs/bigmodel_clone/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train.csv'
