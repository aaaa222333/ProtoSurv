# %%
import pandas as pd

# 读取CSV
df = pd.read_csv("/home/user/prognosis_lst/evaluate_model/feature_similiary/lung1/inference_distance_samples_filtered.csv")

# 1. 查看各列的数据类型
print("各列当前格式:")
print(df.dtypes)

# 2. 查看前几行数据
print("\n前3行数据:")
print(df.head(3))

# 3. 查看每列的唯一值（对分类变量有用）
print("\n每列唯一值示例:")
for col in df.columns:
    print(f"{col}: {df[col].unique()[:5]}")  # 显示前5个唯一值
# Out:
# 各列当前格式:
# feature_path      object
# label              int64
# need_pull           bool
# sim_to_pseudo    float64
# dtype: object
#
# 前3行数据:
#                                         feature_path  label  need_pull  \
# 0  /home/user/prognosis_lst/feature/lung1/pretrai...      0       True
# 1  /home/user/prognosis_lst/feature/lung1/pretrai...      0       True
# 2  /home/user/prognosis_lst/feature/lung1/pretrai...      0       True
#
#    sim_to_pseudo
# 0       0.608882
# 1       0.623232
# 2       0.775764
#
# 每列唯一值示例:
# feature_path: ['/home/user/prognosis_lst/feature/lung1/pretrain/train/000180d4e1c10cb8422f3de1401be6ef.pt'
#  '/home/user/prognosis_lst/feature/lung1/pretrain/train/002309004a98173da5eeae59f64f3e1d.pt'
#  '/home/user/prognosis_lst/feature/lung1/pretrain/train/0043ff47f52f63ff17f50434c475d175.pt'
#  '/home/user/prognosis_lst/feature/lung1/pretrain/train/0047bf7726043b5062e73e028a9d9b4a.pt'
# ...

# %%
df['need_pull'] = df['need_pull'].astype(bool)        # True/False
df['label'] = df['label'].astype(int)   # 0,1,2...
df['sim_to_pseudo'] = df['sim_to_pseudo'].astype(float) # 0.123
df['feature_path'] = df['feature_path'].astype(str)   # 文件路径

# %%
df.to_csv("/home/user/prognosis_lst/evaluate_model/ConvNeXt/data/huaxi/test/final_complete_with_paths_labels.csv", index=False)
